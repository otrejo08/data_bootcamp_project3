# %%
import pandas as pd
import os

# %%
seasons_csv = os.path.join("airbnb_rvw_wSeasons.csv")

# %%
seasons_df = pd.read_csv(seasons_csv, encoding="ISO-8859-1")

# %%
seasons_df.head()
# Out:
#    Unnamed: 0  listing_id     id       date  reviewer_id reviewer_name  \
# 0           1       11156  32592  3/31/2010        99382       Michael
# 1           2       11156  42280  5/14/2010       105797        Marina
# 2           3       12351  68394  7/24/2010        45760          Anna
# 3           4       12936  73473   8/4/2010       111479         Brian
# 4           5       12351  76453   8/9/2010       148786        Stuart
#
#                                             comments  \
# 0  Great place, centrally located, easy walk to t...
# 1  Colleen is very friendly and helpful. The apar...
# 2  This was my first Airbnb experience and I am h...
# 3  Perfect apartment in a perfect location!!!! \r...
# 4  As my first AirBnB experience, this was a magn...
#
#                           listing_name  host_id  listing_latitude  \
# 0                 An Oasis in the City    40855        -33.869342
# 1                 An Oasis in the City    40855        -33.869342
# ...

# %%
cd desktop
# Out:
# /Users/kabrinar/Desktop

# %%
cd PolarizedText\ analysis
# Out:
# /Users/kabrinar/Desktop/PolarizedText analysis

# %%
ls
# Out:
# melbourne_reviews.csv* sydney_reviews.csv*

# %%
Melbourne_reviews_csv = os.path.join("melbourne_reviews.csv")

# %%
Sydney_reviews_csv = os.path.join("sydney_reviews.csv")

# %%
MBreviews_df = pd.read_csv(Melbourne_reviews_csv, encoding="ISO-8859-1")

# %%
SYDreviews_df = pd.read_csv(Sydney_reviews_csv, encoding="ISO-8859-1")

# %%
MBreviews_df.loc[:, ["comments"]]
# Out:
#                                                 comments
# 0      Fantastic place to stay if you are with a grou...
# 1      This property is in a fantastic location with ...
# 2      The space itself is just amazing. Very nice re...
# 3      great experience, the place was as listed and ...
# 4      I was able to contact Rowan easily and he gave...
# 5      This was a beautiful building in a possibly th...
# 6      We (a group of seven - four adults and three c...
# 7      This home was beautiful. Modern, clean and spa...
# 8      Positives:\r\nWarehouse was in a fantastic loc...
# 9      Great place as described, very nicely decorate...
# 10     The detailed instructions to enter the house w...
# 11     This place was perfect in terms of the aparmen...
# 12     My partner and I stayed at Celeste for 5 days ...
# 13     The place is perfect for 2 people! Very close ...
# 14     I have had the pleasure to stay in this lovely...
# ...

# %%
SYDreviews_df.loc[:, ["comments"]]
# Out:
#                                                 comments
# 0                           Listing description accurate
# 1      Lovely location close to everything we needed ...
# 2      Robyn and Ken were lovely. They both looked af...
# 3      I enjoyed staying in this apartment, something...
# 4      Me and my boyfriend stayed at Ingrid's flat in...
# 5      We had an excellent time in Bronte. The photos...
# 6      Ideale Lage fÃ¼r Unternehmungen, tolle Lage, s...
# 7      Our stay with Ingrid was perfect. The location...
# 8      The reservation was canceled 16 days before ar...
# 9      SchÃ¶nes Apartment in perfekter Lage. Kommunik...
# 10     This is a really great little hideaway. I'm re...
# 11     A fantastic location! My family and I stayed h...
# 12     The host canceled this reservation 20 days bef...
# 13     Fantastic location right at the beach. Very cl...
# 14     Judd and Ingrid were great hosts. Easy to comm...
# ...
