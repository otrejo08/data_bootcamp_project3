# %%
import pandas as pd;
from matplotlib import pyplot as plt
import os
import nltk
from nltk import word_tokenize

# %%
def tokenize_text(text):
    words = word_tokenize(text)
    return words
def token_to_char(token_list):
        token = [token for count, token in enumerate(comment_text)
          for token in comment_text[count]]
        chars = [char for count, item in enumerate(tokens)
                for char in token[count]]
        return chars
def char_check(chars, dict_items):
    hurdle = len(chars)
    check = True
    for char in chars:
        if char in dict_items.values():
            check = True
        else:
            check = False
            break
    print('complete')
    return check

# %%
files = ['melbourne_reviews.csv', 'sydney_reviews.csv']
path = '../Merged_Resources/PolarizedText analysis'

# %%
cc = 'melbourne'
dd = [True, True, True, True]
# Out:
# 4

# %%
dict_path = '../Processing'
dict_file = 'CharDict.csv'
full_dict_path = os.path.join(dict_path, dict_file)
char_df = pd.read_csv(full_dict_path)
char_dict = {k:char_df['Symbol'][count] for count, k in enumerate(char_df['Code'])}

# %%
melbourne_rvw = pd.read_csv(os.path.join(path, files[0]))
sydney_rvw = pd.read_csv(os.path.join(path, files[1]))

# %%
air_bnb_rvw = pd.concat([melbourne_rvw, sydney_rvw])
air_bnb_rvw['polarity'].describe()
# Out:
# count    178013.000000
# mean          0.863330
# std           0.267228
# min          -0.997500
# 25%           0.893400
# 50%           0.953800
# 75%           0.977300
# max           0.999600
# Name: polarity, dtype: float64

# %%
#Generate primative tokeniztion for review comment length
polarity_val = sorted(air_bnb_rvw['polarity'].values)
polarity_val = pd.Series(polarity_val, name='Polarity')
x_axis = np.arange(len(polarity_val))
polarity_val.plot(kind='line', figsize=(15,8))
plt.title('Description Length S-Curve', fontsize = 15)
plt.xlabel("Records", fontsize = 10)

plt.tick_params(labelsize=9)
plt.show()
# Out:
# Text(0.5, 1.0, 'Description Length S-Curve')
# Text(0.5, 0, 'Records')

# %%
x_val =air_bnb_rvw['polarity']
x_bins = np.linspace(0,max(x_val),num=150)
x_val.plot.hist(x_bins, linewidth=1.0, edgecolor='k', alpha=0.65, figsize=(15,8))

# %%
comment_text = [tokenize_text(str(comment)) for comment in air_bnb_rvw.comments]

# %%
comment_text[0:5]
# Out:
# [['Fantastic',
#   'place',
#   'to',
#   'stay',
#   'if',
#   'you',
#   'are',
#   'with',
#   'a',
#   'group',
#   'or',
#   'large',
#   'family',
#   '.',
#   'Short',
#   'walk',
#   'to',
#   'a',
#   'myriad',
#   'of',
#   'brilliant',
#   'places',
#   'to',
#   'eat',
#   '.',
#   'Stone-throw',
#   'from',
#   'Richmond',
#   'station',
#   'giving',
#   'easy',
#   'access',
#   'to',
#   'the',
#   'city',
#   '.',
#   'Layout',
#   'of',
#   'the',
#   'house',
#   'worked',
#   'well',
#   '-',
#   'we',
#   'especially',
#   'enjoyed',
#   'the',
#   'stunning',
#   'views',
#   'from',
#   'the',
#   'top',
#   'floor',
#   'balcony',
#   '.',
#   'Would',
#   'definitely',
#   'book',
#   'again',
#   '.',
#   'Many',
#   'thanks',
#   '!'],
#  ['This',
#   'property',
#   'is',
#   'in',
#   'a',
#   'fantastic',
#   'location',
#   'with',
#   'wonderful',
#   'views',
#   'of',
#   'the',
#   'city',
#   '.',
#   'Rowan',
#   'was',
#   'prompt',
#   'in',
# ...

# %%
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
